# %%
from src import FtLinearRegression as LR
lr = LR(0.0175)

# %%
lr.read_csv('src/data.csv')
lr.fit_intern_data()
lr.predict(27000)
# Out:
# Initial Mean Squared Error: 0.267025
# Final Mean Squared Error: 0.267025
# np.float64(7920.477632957249)

# %%
lr.plot()
# Out:
# Gráfico salvo como 'plot.png'
